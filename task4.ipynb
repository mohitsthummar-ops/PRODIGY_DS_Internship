# %% [markdown]
# ## Perform Sentiment Analysis
#
# Analyze the sentiment of the text in the generated dataset `df_social_media`. This step will involve processing the text to determine its emotional tone or opinion, categorizing it into predefined sentiment classes.

# %%
from textblob import TextBlob

# 2. Define a function to get sentiment label based on polarity
def get_sentiment_label(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity < 0:
        return 'negative'
    else:
        return 'neutral'

df_social_media['predicted_sentiment'] = df_social_media['text'].apply(get_sentiment_label)

print("DataFrame with predicted sentiment:")
df_social_media.head()
# Out:
# DataFrame with predicted sentiment:
#                                                 text sentiment  \
# 0                Loving this new movie! So exciting!  positive
# 1  This restaurant was a huge disappointment. Ser...  negative
# 2           Just a regular Tuesday, nothing special.   neutral
# 3                What a beautiful day to be outside!  positive
# 4  Feeling really down today, everything is going...  negative
#
#   predicted_sentiment
# 0            positive
# 1            negative
# 2            positive
# 3            positive
# 4            negative

# %% [markdown]
# ## Visualize Sentiment Patterns
#
# Create a visualization (e.g., a bar chart or pie chart) to display the distribution of sentiment categories (positive, negative, neutral) across the dataset, highlighting the overall public opinion or attitudes. Ensure to include a legend for the visualization.

# %%
import matplotlib.pyplot as plt

sentiment_counts = df_social_media['predicted_sentiment'].value_counts()

plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Distribution of Predicted Sentiment')
plt.xlabel('Sentiment Category')
plt.ylabel('Number of Posts')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

sentiment_counts = df_social_media['predicted_sentiment'].value_counts()

plt.figure(figsize=(8, 6))
ax = sentiment_counts.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])

plt.title('Distribution of Predicted Sentiment')
plt.xlabel('Sentiment Category')
plt.ylabel('Number of Posts')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

sentiment_labels = sentiment_counts.index.tolist()
sentiment_colors = ['skyblue', 'lightcoral', 'lightgreen']

patch_list = []
for i, label in enumerate(sentiment_labels):
    patch_list.append(mpatches.Patch(color=sentiment_colors[i], label=label))

plt.legend(handles=patch_list, title='Sentiment')

plt.show()

# %% [markdown]
# ## Final Task
#
# Provide a summary of the observed sentiment patterns and any insights gained from the analysis and visualization, relating them to public opinion or attitudes towards specific topics/brands.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The analysis identified the distribution of sentiment patterns within the simulated social media data. The overall public opinion, as derived from the `predicted_sentiment`, leans predominantly positive, followed by a significant negative sentiment, and a smaller neutral category.
#
# ### Data Analysis Key Findings
# *   **Dummy Data Generation**: A synthetic dataset of 12 social media-like texts was created, each assigned an initial sentiment label (5 positive, 5 negative, 2 neutral).
# *   **Sentiment Prediction Discrepancy**: While performing sentiment analysis using TextBlob, one instance of originally 'neutral' sentiment ("Just a regular Tuesday, nothing special.") was re-categorized as 'positive' by the prediction model.
# *   **Predicted Sentiment Distribution**: After TextBlob analysis, the sentiment distribution across the dataset shifted to 6 positive, 5 negative, and 1 neutral entries.
# *   **Visual Confirmation**: A bar chart was successfully generated, visually representing this distribution, indicating 'positive' as the most frequent sentiment category, followed by 'negative', and then 'neutral'.
