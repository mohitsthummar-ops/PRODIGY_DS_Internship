# %% [markdown]
# ### Bar Chart for Categorical Variable (Gender)
#
# This bar chart visualizes the distribution of the 'Gender' variable.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', hue='Gender', data=df, palette='viridis', legend=False)
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Histogram for Continuous Variable (Age)
#
# This histogram visualizes the distribution of the 'Age' variable.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=10, kde=True, color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Histogram for Continuous Variable (Score)
#
# This histogram visualizes the distribution of the 'Score' variable.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Score'], bins=15, kde=True, color='lightcoral')
plt.title('Distribution of Score')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
