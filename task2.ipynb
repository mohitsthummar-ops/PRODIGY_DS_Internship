# %% [markdown]
# ## Initial Data Inspection
#
# Load the created dataset into a pandas DataFrame and perform initial inspections, such as checking data types, basic statistics, and identifying missing values.

# %%
print("Displaying the first 5 rows of the DataFrame:")
print(df.head())

print("\nGetting a concise summary of the DataFrame:")
df.info()

print("\nCalculating descriptive statistics for numerical columns:")
print(df.describe())

print("\nChecking for missing values in each column:")
print(df.isnull().sum())
# Out:
# Displaying the first 5 rows of the DataFrame:
#    Numerical_1  Numerical_2 Categorical_1 Categorical_2
# 0           10      10.5000             A             X
# 1           20      20.1000             B             Y
# 2           30      56.6875             A             Z
# 3           40      40.8000             C             X
# 4           50      50.3000             B             X
#
# Getting a concise summary of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Numerical_1    10 non-null     int64
#  1   Numerical_2    10 non-null     float64
#  2   Categorical_1  10 non-null     object
#  3   Categorical_2  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes
#
# Calculating descriptive statistics for numerical columns:
#        Numerical_1  Numerical_2
# ...

# %% [markdown]
# ## Handle Missing Values
#
# Address any missing values in the dataset. This might involve imputation or removal, depending on the nature of the data.

# %%
print("Filling missing values in 'Numerical_2' with its mean...")
mean_numerical_2 = df['Numerical_2'].mean()
df['Numerical_2'] = df['Numerical_2'].fillna(mean_numerical_2)

print("Filling missing values in 'Categorical_2' with its mode...")
mode_categorical_2 = df['Categorical_2'].mode()[0]
df['Categorical_2'] = df['Categorical_2'].fillna(mode_categorical_2)

print("\nVerifying that all missing values have been handled:")
print(df.isnull().sum())
# Out:
# Filling missing values in 'Numerical_2' with its mean...
# Filling missing values in 'Categorical_2' with its mode...
#
# Verifying that all missing values have been handled:
# Numerical_1      0
# Numerical_2      0
# Categorical_1    0
# Categorical_2    0
# dtype: int64

# %% [markdown]
# ## Descriptive Statistics
#
# Calculate and display descriptive statistics for the numerical columns of the cleaned dataset to understand their central tendency, dispersion, and shape.

# %%
print("Descriptive statistics for numerical columns:")
print(df.describe())
# Out:
# Descriptive statistics for numerical columns:
#        Numerical_1  Numerical_2
# count    10.000000    10.000000
# mean     55.000000    56.687500
# std      30.276504    28.613417
# min      10.000000    10.500000
# 25%      32.500000    43.175000
# 50%      55.000000    56.687500
# 75%      77.500000    75.375000
# max     100.000000   100.000000

# %% [markdown]
# ## Visualize Data Distribution
#
# Generate plots (e.g., histograms for numerical data, bar plots for categorical data) to visualize the distribution of key variables in the dataset. Ensure plots have legends.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

print("Generating histograms for numerical data:")
fig1, axes1 = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df['Numerical_1'], kde=True, ax=axes1[0], color='skyblue')
axes1[0].set_title('Distribution of Numerical_1')
axes1[0].set_xlabel('Numerical_1 Value')
axes1[0].set_ylabel('Frequency')

sns.histplot(df['Numerical_2'], kde=True, ax=axes1[1], color='lightcoral')
axes1[1].set_title('Distribution of Numerical_2')
axes1[1].set_xlabel('Numerical_2 Value')
axes1[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

print("\nGenerating bar plots for categorical data:")
fig2, axes2 = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(x=df['Categorical_1'], ax=axes2[0], palette='viridis')
axes2[0].set_title('Distribution of Categorical_1')
axes2[0].set_xlabel('Category')
axes2[0].set_ylabel('Count')

sns.countplot(x=df['Categorical_2'], ax=axes2[1], palette='plasma')
axes2[1].set_title('Distribution of Categorical_2')
axes2[1].set_xlabel('Category')
axes2[1].set_ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# Generating histograms for numerical data:
# Generating bar plots for categorical data:
# /tmp/ipython-input-572/880293478.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Categorical_1'], ax=axes2[0], palette='viridis')
# /tmp/ipython-input-572/880293478.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Categorical_2'], ax=axes2[1], palette='plasma')

# %% [markdown]
# **Reasoning**:
# The previous code generated a `FutureWarning` because `palette` was used in `sns.countplot` without specifying a `hue` argument. To resolve this and align with future Seaborn versions, I will explicitly set `hue` to the same column as `x` and set `legend=False` as suggested by the warning.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

print("Generating histograms for numerical data:")
fig1, axes1 = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(df['Numerical_1'], kde=True, ax=axes1[0], color='skyblue')
axes1[0].set_title('Distribution of Numerical_1')
axes1[0].set_xlabel('Numerical_1 Value')
axes1[0].set_ylabel('Frequency')

sns.histplot(df['Numerical_2'], kde=True, ax=axes1[1], color='lightcoral')
axes1[1].set_title('Distribution of Numerical_2')
axes1[1].set_xlabel('Numerical_2 Value')
axes1[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

print("\nGenerating bar plots for categorical data:")
fig2, axes2 = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(x=df['Categorical_1'], hue=df['Categorical_1'], ax=axes2[0], palette='viridis', legend=False)
axes2[0].set_title('Distribution of Categorical_1')
axes2[0].set_xlabel('Category')
axes2[0].set_ylabel('Count')

sns.countplot(x=df['Categorical_2'], hue=df['Categorical_2'], ax=axes2[1], palette='plasma', legend=False)
axes2[1].set_title('Distribution of Categorical_2')
axes2[1].set_xlabel('Category')
axes2[1].set_ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# Generating histograms for numerical data:
# Generating bar plots for categorical data:

# %% [markdown]
# ## Explore Relationships Between Variables
#
# Create visualizations (e.g., scatter plots, box plots, or correlation matrix heatmap) to explore relationships between different variables in the dataset. Ensure plots have legends.

# %%
print("Generating scatter plot for Numerical_1 vs Numerical_2:")
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Numerical_1', y='Numerical_2', data=df, hue='Categorical_1', palette='deep')
plt.title('Scatter Plot of Numerical_1 vs Numerical_2')
plt.xlabel('Numerical_1')
plt.ylabel('Numerical_2')
plt.legend(title='Categorical_1')
plt.grid(True)
plt.show()

print("\nGenerating box plots for numerical data across categorical variables:")
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

sns.boxplot(x='Categorical_1', y='Numerical_1', data=df, ax=axes[0, 0], palette='viridis')
axes[0, 0].set_title('Distribution of Numerical_1 by Categorical_1')
axes[0, 0].set_xlabel('Categorical_1')
axes[0, 0].set_ylabel('Numerical_1')

sns.boxplot(x='Categorical_1', y='Numerical_2', data=df, ax=axes[0, 1], palette='viridis')
axes[0, 1].set_title('Distribution of Numerical_2 by Categorical_1')
axes[0, 1].set_xlabel('Categorical_1')
axes[0, 1].set_ylabel('Numerical_2')

sns.boxplot(x='Categorical_2', y='Numerical_1', data=df, ax=axes[1, 0], palette='plasma')
axes[1, 0].set_title('Distribution of Numerical_1 by Categorical_2')
axes[1, 0].set_xlabel('Categorical_2')
axes[1, 0].set_ylabel('Numerical_1')

sns.boxplot(x='Categorical_2', y='Numerical_2', data=df, ax=axes[1, 1], palette='plasma')
axes[1, 1].set_title('Distribution of Numerical_2 by Categorical_2')
axes[1, 1].set_xlabel('Categorical_2')
axes[1, 1].set_ylabel('Numerical_2')

plt.tight_layout()
plt.show()

print("\nCalculating and displaying correlation matrix heatmap for numerical columns:")
numerical_cols = ['Numerical_1', 'Numerical_2']
correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Variables')
plt.show()
# Out:
# Generating scatter plot for Numerical_1 vs Numerical_2:
# Generating box plots for numerical data across categorical variables:
# /tmp/ipython-input-572/1496883118.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Categorical_1', y='Numerical_1', data=df, ax=axes[0, 0], palette='viridis')
# /tmp/ipython-input-572/1496883118.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Categorical_1', y='Numerical_2', data=df, ax=axes[0, 1], palette='viridis')
# /tmp/ipython-input-572/1496883118.py:27: FutureWarning:
#
# ...

# %% [markdown]
# **Reasoning**:
# The previous code generated `FutureWarning` messages for `sns.boxplot` due to using the `palette` argument without explicitly setting the `hue` argument. To fix this and align with future Seaborn versions, I will modify the `sns.boxplot` calls to include `hue=df[categorical_column]` and `legend=False` as suggested by the warning.

# %%
print("Generating scatter plot for Numerical_1 vs Numerical_2:")
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Numerical_1', y='Numerical_2', data=df, hue='Categorical_1', palette='deep')
plt.title('Scatter Plot of Numerical_1 vs Numerical_2')
plt.xlabel('Numerical_1')
plt.ylabel('Numerical_2')
plt.legend(title='Categorical_1')
plt.grid(True)
plt.show()

print("\nGenerating box plots for numerical data across categorical variables:")
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

sns.boxplot(x='Categorical_1', y='Numerical_1', data=df, ax=axes[0, 0], palette='viridis', hue='Categorical_1', legend=False)
axes[0, 0].set_title('Distribution of Numerical_1 by Categorical_1')
axes[0, 0].set_xlabel('Categorical_1')
axes[0, 0].set_ylabel('Numerical_1')

sns.boxplot(x='Categorical_1', y='Numerical_2', data=df, ax=axes[0, 1], palette='viridis', hue='Categorical_1', legend=False)
axes[0, 1].set_title('Distribution of Numerical_2 by Categorical_1')
axes[0, 1].set_xlabel('Categorical_1')
axes[0, 1].set_ylabel('Numerical_2')

sns.boxplot(x='Categorical_2', y='Numerical_1', data=df, ax=axes[1, 0], palette='plasma', hue='Categorical_2', legend=False)
axes[1, 0].set_title('Distribution of Numerical_1 by Categorical_2')
axes[1, 0].set_xlabel('Categorical_2')
axes[1, 0].set_ylabel('Numerical_1')

sns.boxplot(x='Categorical_2', y='Numerical_2', data=df, ax=axes[1, 1], palette='plasma', hue='Categorical_2', legend=False)
axes[1, 1].set_title('Distribution of Numerical_2 by Categorical_2')
axes[1, 1].set_xlabel('Categorical_2')
axes[1, 1].set_ylabel('Numerical_2')

plt.tight_layout()
plt.show()

print("\nCalculating and displaying correlation matrix heatmap for numerical columns:")
numerical_cols = ['Numerical_1', 'Numerical_2']
correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Variables')
plt.show()
# Out:
# Generating scatter plot for Numerical_1 vs Numerical_2:
# Generating box plots for numerical data across categorical variables:
# Calculating and displaying correlation matrix heatmap for numerical columns:

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the key findings from the data cleaning and exploratory data analysis, highlighting any identified patterns or trends.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Initial Data State**: The dataset consisted of 10 entries and 4 columns: two numerical (`Numerical_1`, `Numerical_2`) and two categorical (`Categorical_1`, `Categorical_2`).
#     *   `Numerical_1` and `Categorical_1` had no missing values.
#     *   `Numerical_2` and `Categorical_2` each had 2 missing values.
# *   **Missing Value Handling**:
#     *   Missing values in `Numerical_2` were successfully imputed with its mean, which was approximately 56.69.
#     *   Missing values in `Categorical_2` were successfully imputed with its mode (most frequent category).
# *   **Descriptive Statistics**:
#     *   **Numerical\_1**: Ranged from 10 to 100, with a mean of 55.0 and a standard deviation of 30.28. The median was 55.0.
#     *   **Numerical\_2**: After imputation, its values ranged from 10.5 to 100.0, with a mean of 56.69 and a standard deviation of 28.61. The median was 56.69.
# *   **Data Distributions**:
#     *   **Numerical\_1** and **Numerical\_2**: Both numerical variables exhibited distributions spread across their respective ranges, with no obvious strong skewness or unusual patterns immediately visible from histograms, suggesting a relatively uniform-like or broadly distributed set of values in this small dataset.
#     *   **Categorical\_1**: Showed categories 'A', 'B', 'C' with frequencies of 4, 3, and 3 respectively.
#     *   **Categorical\_2**: Showed categories 'X', 'Y', 'Z' with frequencies of 3, 2, and 5 respectively (after imputation).
# *   **Relationships Between Variables**:
#     *   **Numerical\_1 vs. Numerical\_2 (Scatter Plot)**: There appears to be a strong positive linear relationship between `Numerical_1` and `Numerical_2`, indicating that as `Numerical_1` increases, `Numerical_2` also tends to increase.
#     *   **Numerical vs. Categorical (Box Plots)**:
#         *   For both `Numerical_1` and `Numerical_2`, the distributions across `Categorical_1` categories ('A', 'B', 'C') showed distinct ranges and medians, suggesting that `Categorical_1` might be a factor influencing the numerical values.
#         *   Similarly, `Categorical_2` categories ('X', 'Y', 'Z') also showed variations in the distributions of `Numerical_1` and `Numerical_2`.
#     *   **Correlation Matrix**: A heatmap confirmed a high positive correlation of 0.99 between `Numerical_1` and `Numerical_2`, reinforcing the observation from the scatter plot.
